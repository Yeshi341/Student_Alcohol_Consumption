# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('student-por.csv')

# %% [markdown]
# http://www3.dsi.uminho.pt/pcortez/student.pdf
# https://archive.ics.uci.edu/ml/datasets/student%2Bperformance#

# %%
print('Rows and Columns :', df.shape,'\n' )

print('INFO:')
print(df.info(), '\n')
print('df Columns:', df.columns, '\n')
print('Unique Values :','\n', df.nunique(), '\n')
# Out:
# Rows and Columns : (649, 33)
#
# INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# freetime      649 non-null int64
# goout         649 non-null int64
# Dalc          649 non-null int64
# Walc          649 non-null int64
# health        649 non-null int64
# absences      649 non-null int64
# G1            649 non-null int64
# G2            649 non-null int64
# G3            649 non-null int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB
# None
#
# df Columns: Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')
#
# Unique Values :
#  school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      24
# G1            17
# G2            16
# G3            17
# dtype: int64

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         0       yes     no   no
# 3    home   mother           1          3         0        no    yes   no
# 4    home   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0         no     yes    yes       no       no       4         3      4     1
# 1         no      no    yes      yes       no       5         3      3     1
# 2         no     yes    yes      yes       no       4         3      2     2
# 3        yes     yes    yes      yes      yes       3         2      2     1
# 4         no     yes    yes       no       no       4         3      2     1
#
#    Walc  health  absences  G1  G2  G3
# 0     1       3         4   0  11  11
# 1     1       3         2   9  11  11
# 2     3       3         6  12  13  12
# 3     1       5         0  14  14  14
# 4     2       5         0  11  13  13

# %%
df['Mjob'].value_counts()
# Out:
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: Mjob, dtype: int64

# %%
df['Fjob'].value_counts()
# Out:
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: Fjob, dtype: int64

# %%
df['failures'].value_counts()
# Out:
# 0    549
# 1     70
# 2     16
# 3     14
# Name: failures, dtype: int64

# %% [markdown]
# dropping extraneous columns

# %%
df.drop(['school', 'address', 'Mjob', 'Fjob', 'reason', 'guardian', 'romantic','traveltime', 'nursery','health'], axis = 1, inplace = True)

# %% [markdown]
# removing students outside of high school age

# %%
df = df[df['age'] <= 18] 
np.sqrt(df.shape[0])
# Out:
# 24.657656011875904

# %%
df.head(10)
# Out:
#   sex  age famsize Pstatus  Medu  Fedu  studytime  failures schoolsup famsup  \
# 0   F   18     GT3       A     4     4          2         0       yes     no
# 1   F   17     GT3       T     1     1          2         0        no    yes
# 2   F   15     LE3       T     1     1          2         0       yes     no
# 3   F   15     GT3       T     4     2          3         0        no    yes
# 4   F   16     GT3       T     3     3          2         0        no    yes
# 5   M   16     LE3       T     4     3          2         0        no    yes
# 6   M   16     LE3       T     2     2          2         0        no     no
# 7   F   17     GT3       A     4     4          2         0       yes    yes
# 8   M   15     LE3       A     3     2          2         0        no    yes
# 9   M   15     GT3       T     3     4          2         0        no    yes
#
#   paid activities higher internet  famrel  freetime  goout  Dalc  Walc  \
# 0   no         no    yes       no       4         3      4     1     1
# 1   no         no    yes      yes       5         3      3     1     1
# 2   no         no    yes      yes       4         3      2     2     3
# 3   no        yes    yes      yes       3         2      2     1     1
# 4   no         no    yes       no       4         3      2     1     2
# 5   no        yes    yes      yes       5         4      2     1     2
# 6   no         no    yes      yes       4         4      4     1     1
# 7   no         no    yes       no       4         1      4     1     1
# 8   no         no    yes      yes       4         2      2     1     1
# 9   no        yes    yes      yes       5         5      1     1     1
#
#    absences  G1  G2  G3
# 0         4   0  11  11
# 1         2   9  11  11
# 2         6  12  13  12
# 3         0  14  14  14
# 4         0  11  13  13
# 5         6  12  12  13
# 6         0  13  12  13
# 7         2  10  13  13
# 8         0  15  16  17
# 9         0  12  12  13

# %% [markdown]
# renaming famsize to siblings and changing value to a binary

# %%
df.rename(columns ={'famsize':'siblings'}, inplace = True)

df.loc[(df.siblings == 'GT3'), 'siblings'] = 1
df.loc[(df.siblings == 'LE3'), 'siblings'] = 0

df.head()
# Out:
#   sex  age  siblings Pstatus  Medu  Fedu  studytime  failures schoolsup  \
# 0   F   18         1       A     4     4          2         0       yes
# 1   F   17         1       T     1     1          2         0        no
# 2   F   15         0       T     1     1          2         0       yes
# 3   F   15         1       T     4     2          3         0        no
# 4   F   16         1       T     3     3          2         0        no
#
#   famsup paid activities higher internet  famrel  freetime  goout  Dalc  Walc  \
# 0     no   no         no    yes       no       4         3      4     1     1
# 1    yes   no         no    yes      yes       5         3      3     1     1
# 2     no   no         no    yes      yes       4         3      2     2     3
# 3    yes   no        yes    yes      yes       3         2      2     1     1
# 4    yes   no         no    yes       no       4         3      2     1     2
#
#    absences  G1  G2  G3
# 0         4   0  11  11
# 1         2   9  11  11
# 2         6  12  13  12
# 3         0  14  14  14
# 4         0  11  13  13

# %% [markdown]
# Converting all binary non-numeric variables to numeric variables

# %%
df.loc[df.sex== 'F', 'sex'] = 1
df.loc[df.sex == 'M', 'sex'] = 0

df.loc[(df.Pstatus == 'T'), 'Pstatus'] = 2
df.loc[(df.Pstatus == 'A'), 'Pstatus'] = 1

df.loc[(df.schoolsup == 'yes'), 'schoolsup'] = 1
df.loc[(df.schoolsup == 'no'), 'schoolsup'] = 0

df.loc[(df.famsup == 'yes'), 'famsup'] = 1
df.loc[(df.famsup == 'no'), 'famsup'] = 0

df.loc[(df.paid == 'yes'), 'paid'] = 1
df.loc[(df.paid == 'no'), 'paid'] = 0

df.loc[(df.activities == 'yes'), 'activities'] = 1
df.loc[(df.activities == 'no'), 'activities'] = 0

df.loc[(df.higher == 'yes'), 'higher'] = 1
df.loc[(df.higher == 'no'), 'higher'] = 0

df.loc[(df.internet == 'yes'), 'internet'] = 1
df.loc[(df.internet == 'no'), 'internet'] = 0

# %% [markdown]
# dummy variables for age column and drop 'age'

# %%
ages_dummies = pd.get_dummies(df.age, prefix = 'age').iloc[:,1:]

df = pd.concat([df, ages_dummies], axis = 1)
df.drop('age', axis = 1)
# Out:
#      sex  siblings  Pstatus  Medu  Fedu  studytime  failures  schoolsup  \
# 0      1         1        1     4     4          2         0          1
# 1      1         1        2     1     1          2         0          0
# 2      1         0        2     1     1          2         0          1
# 3      1         1        2     4     2          3         0          0
# 4      1         1        2     3     3          2         0          0
# ..   ...       ...      ...   ...   ...        ...       ...        ...
# 643    1         1        2     4     4          1         0          0
# 645    1         0        2     3     1          2         0          0
# 646    1         1        2     1     1          2         0          0
# 647    0         0        2     3     1          1         0          0
# 648    0         0        2     3     2          1         0          0
#
#      famsup  paid  activities  higher  internet  famrel  freetime  goout  \
# 0         0     0           0       1         0       4         3      4
# 1         1     0           0       1         1       5         3      3
# 2         0     0           0       1         1       4         3      2
# 3         1     0           1       1         1       3         2      2
# 4         1     0           0       1         0       4         3      2
# ..      ...   ...         ...     ...       ...     ...       ...    ...
# 643       1     0           1       1         1       4         4      3
# 645       1     0           0       1         1       4         3      4
# 646       0     0           1       1         0       1         1      1
# 647       0     0           0       1         1       2         4      5
# 648       0     0           0       1         1       4         4      1
#
#      Dalc  Walc  absences  G1  G2  G3  age_16  age_17  age_18
# 0       1     1         4   0  11  11       0       0       1
# 1       1     1         2   9  11  11       0       1       0
# 2       2     3         6  12  13  12       0       0       0
# 3       1     1         0  14  14  14       0       0       0
# 4       1     2         0  11  13  13       1       0       0
# ..    ...   ...       ...  ..  ..  ..     ...     ...     ...
# 643     2     2         4   7   9  10       0       0       1
# 645     1     1         4  15  15  16       0       0       1
# 646     1     1         6  11  12   9       0       0       1
# 647     3     4         6  10  10  10       0       1       0
# 648     3     4         4  10  11  11       0       0       1
#
# [608 rows x 25 columns]

# %% [markdown]
# creating target variable quantifying alchohol consumption, and dropping 'Walc' and 'Dalc'

# %%
df['tot_alc'] = df.Dalc + df.Walc
df.drop(['Walc', 'Dalc'], axis = 1, inplace = True)

# %% [markdown]
# feature quantifying famility stability feature

# %%
df['stability'] = df.Pstatus*df.famrel+(df.Fedu + df.Medu)

# %%
df.head(1)
# Out:
#    sex  age  siblings  Pstatus  Medu  Fedu  studytime  failures  schoolsup  \
# 0    1   18         1        1     4     4          2         0          1
#
#    famsup  paid  activities  higher  internet  famrel  freetime  goout  \
# 0       0     0           0       1         0       4         3      4
#
#    absences  G1  G2  G3  age_16  age_17  age_18  tot_alc  stability
# 0         4   0  11  11       0       0       1        2         12

# %% [markdown]
# feature quantifying academic support network

# %%
df['academic_support'] = df.famsup + df.schoolsup + df.paid + df.Medu + df.Fedu + df.higher + df.internet

# %% [markdown]
# feature averaging grade

# %%
df['grade_avg'] = round((df.G1 + df.G2 + df.G3)/3, 2)

# %%
df.corr()
# Out:
#                        sex       age  siblings   Pstatus      Medu      Fedu  \
# sex               1.000000  0.061678  0.106622 -0.064509 -0.118618 -0.103302
# age_16           -0.413948 -0.350501 -0.043545  -0.021689          0.000367
# age_17            1.000000 -0.353296  0.070590   0.000794         -0.051514
# age_18           -0.353296  1.000000  0.052123  -0.030742         -0.058928
# tot_alc           0.070590  0.052123  1.000000  -0.018590         -0.007152
# stability         0.000794 -0.030742 -0.018590   1.000000          0.646203
# academic_support -0.051514 -0.058928 -0.007152   0.646203          1.000000
# grade_avg         0.026980 -0.056331 -0.205069   0.207033          0.254630
#
#                   grade_avg
# sex                0.128732
# age               -0.042588
# siblings          -0.030925
# Pstatus            0.005514
# Medu               0.240945
# Fedu               0.196762
# studytime          0.256090
# failures          -0.376474
# schoolsup         -0.079965
# famsup             0.039213
# paid              -0.066824
# activities         0.060782
# higher             0.324504
# internet           0.137323
# famrel             0.070349
# freetime          -0.099320
# goout             -0.079273
# absences          -0.130834
# G1                 0.936505
# G2                 0.973342
# G3                 0.961130
# age_16             0.005324
# age_17             0.026980
# age_18            -0.056331
# tot_alc           -0.205069
# stability          0.207033
# academic_support   0.254630
# grade_avg          1.000000

# %%
df.head()
# Out:
#    sex  age  siblings  Pstatus  Medu  Fedu  studytime  failures  schoolsup  \
# 0    1   18         1        1     4     4          2         0          1
# 1    1   17         1        2     1     1          2         0          0
# 2    1   15         0        2     1     1          2         0          1
# 3    1   15         1        2     4     2          3         0          0
# 4    1   16         1        2     3     3          2         0          0
#
#    famsup  paid  activities  higher  internet  famrel  freetime  goout  \
# 0       0     0           0       1         0       4         3      4
# 1       1     0           0       1         1       5         3      3
# 2       0     0           0       1         1       4         3      2
# 3       1     0           1       1         1       3         2      2
# 4       1     0           0       1         0       4         3      2
#
#    absences  G1  G2  G3  age_16  age_17  age_18  tot_alc  stability  \
# 0         4   0  11  11       0       0       1        2         12
# 1         2   9  11  11       0       1       0        2         12
# 2         6  12  13  12       0       0       0        5         10
# 3         0  14  14  14       0       0       0        2         12
# 4         0  11  13  13       1       0       0        3         14
#
#    academic_support  grade_avg
# 0                10       7.33
# 1                 5      10.33
# 2                 5      12.33
# 3                 9      14.00
# 4                 8      12.33

# %%
df[df.tot_alc > 0]
# Out:
#      sex  age  siblings  Pstatus  Medu  Fedu  studytime  failures  schoolsup  \
# 0      1   18         1        1     4     4          2         0          1
# 1      1   17         1        2     1     1          2         0          0
# 2      1   15         0        2     1     1          2         0          1
# 3      1   15         1        2     4     2          3         0          0
# 4      1   16         1        2     3     3          2         0          0
# ..   ...  ...       ...      ...   ...   ...        ...       ...        ...
# 643    1   18         1        2     4     4          1         0          0
# 645    1   18         0        2     3     1          2         0          0
# 646    1   18         1        2     1     1          2         0          0
# 647    0   17         0        2     3     1          1         0          0
# 648    0   18         0        2     3     2          1         0          0
#
#      famsup  paid  activities  higher  internet  famrel  freetime  goout  \
# 0         0     0           0       1         0       4         3      4
# 1         1     0           0       1         1       5         3      3
# 2         0     0           0       1         1       4         3      2
# 3         1     0           1       1         1       3         2      2
# 4         1     0           0       1         0       4         3      2
# ..      ...   ...         ...     ...       ...     ...       ...    ...
# 643       1     0           1       1         1       4         4      3
# 645       1     0           0       1         1       4         3      4
# 646       0     0           1       1         0       1         1      1
# 647       0     0           0       1         1       2         4      5
# 648       0     0           0       1         1       4         4      1
#
#      absences  G1  G2  G3  age_16  age_17  age_18  tot_alc  stability  \
# 0           4   0  11  11       0       0       1        2         12
# 1           2   9  11  11       0       1       0        2         12
# 2           6  12  13  12       0       0       0        5         10
# 3           0  14  14  14       0       0       0        2         12
# 4           0  11  13  13       1       0       0        3         14
# ..        ...  ..  ..  ..     ...     ...     ...      ...        ...
# 643         4   7   9  10       0       0       1        4         16
# 645         4  15  15  16       0       0       1        2         12
# 646         6  11  12   9       0       0       1        2          4
# 647         6  10  10  10       0       1       0        7          8
# 648         4  10  11  11       0       0       1        7         13
#
#      academic_support  grade_avg
# 0                  10       7.33
# 1                   5      10.33
# 2                   5      12.33
# 3                   9      14.00
# 4                   8      12.33
# ..                ...        ...
# 643                11       8.67
# 645                 7      15.33
# 646                 3      10.67
# 647                 6      10.00
# 648                 7      10.67
#
# [608 rows x 28 columns]

# %% [markdown]
# quantifying excessive alc

# %%
highest = df.tot_alc.max()
highest
# Out:
# 10

# %%
x = df.tot_alc.mean()
y = df.tot_alc.std()
too_much = round((x + y))
print(too_much)
# Out:
# 6

# %%
bins = [1, 5, 10]
drinking_categories = ['light', 'heavy']

# %%
drinking_bins = pd.cut(df.tot_alc, bins, labels = drinking_categories)

# %%
df = pd.concat([df, drinking_bins], axis = 1)
df.head(20)
# Out:
#     sex  age  siblings  Pstatus  Medu  Fedu  studytime  failures  schoolsup  \
# 0     1   18         1        1     4     4          2         0          1
# 1     1   17         1        2     1     1          2         0          0
# 2     1   15         0        2     1     1          2         0          1
# 3     1   15         1        2     4     2          3         0          0
# 4     1   16         1        2     3     3          2         0          0
# 5     0   16         0        2     4     3          2         0          0
# 6     0   16         0        2     2     2          2         0          0
# 7     1   17         1        1     4     4          2         0          1
# 8     0   15         0        1     3     2          2         0          0
# 9     0   15         1        2     3     4          2         0          0
# 10    1   15         1        2     4     4          2         0          0
# 11    1   15         1        2     2     1          3         0          0
# 12    0   15         0        2     4     4          1         0          0
# 13    0   15         1        2     4     3          2         0          0
# 14    0   15         1        1     2     2          3         0          0
# 15    1   16         1        2     4     4          1         0          0
# 16    1   16         1        2     4     4          3         0          0
# 17    1   16         1        2     3     3          2         0          1
# 18    0   17         1        2     3     2          1         3          0
# 19    0   16         0        2     4     3          1         0          0
#
#     famsup  paid  activities  higher  internet  famrel  freetime  goout  \
# 0        0     0           0       1         0       4         3      4
# 1        1     0           0       1         1       5         3      3
# 2        0     0           0       1         1       4         3      2
# 3        1     0           1       1         1       3         2      2
# 4        1     0           0       1         0       4         3      2
# 5        1     0           1       1         1       5         4      2
# 6        0     0           0       1         1       4         4      4
# 7        1     0           0       1         0       4         1      4
# 8        1     0           0       1         1       4         2      2
# 9        1     0           1       1         1       5         5      1
# 10       1     0           0       1         1       3         3      3
# 11       1     0           1       1         1       5         2      2
# 12       1     0           1       1         1       4         3      3
# 13       1     0           0       1         1       5         4      3
# 14       1     0           0       1         1       4         5      2
# 15       1     0           0       1         1       4         4      4
# 16       1     0           1       1         1       3         2      3
# 17       1     0           1       1         0       5         3      2
# 18       1     1           1       1         1       5         5      5
# 19       0     0           1       1         1       3         1      3
#
#     absences  G1  G2  G3  age_16  age_17  age_18 tot_alc  stability  \
# 0          4   0  11  11       0       0       1       2         12
# 1          2   9  11  11       0       1       0       2         12
# 2          6  12  13  12       0       0       0       5         10
# 3          0  14  14  14       0       0       0       2         12
# 4          0  11  13  13       1       0       0       3         14
# 5          6  12  12  13       1       0       0       3         17
# 6          0  13  12  13       1       0       0       2         12
# 7          2  10  13  13       0       1       0       2         12
# 8          0  15  16  17       0       0       0       2          9
# 9          0  12  12  13       0       0       0       2         17
# 10         2  14  14  14       0       0       0       3         14
# 11         0  10  12  13       0       0       0       2         13
# 12         0  12  13  12       0       0       0       4         16
# 13         0  12  12  13       0       0       0       3         17
# 14         0  14  14  15       0       0       0       2          8
# 15         6  17  17  17       1       0       0       3         16
# 16        10  13  13  14       1       0       0       3         14
# 17         2  13  14  14       1       0       0       2         16
# 18         2   8   8   7       0       1       0       6         15
# 19         6  12  12  12       1       0       0       4         13
#
#     academic_support  grade_avg tot_alc
# 0                 10       7.33   light
# 1                  5      10.33   light
# 2                  5      12.33   light
# 3                  9      14.00   light
# 4                  8      12.33   light
# 5                 10      12.33   light
# 6                  6      12.67   light
# 7                 11      12.00   light
# 8                  8      16.00   light
# 9                 10      12.33   light
# 10                11      14.00   light
# 11                 6      11.67   light
# 12                11      12.33   light
# 13                10      12.33   light
# 14                 7      14.33   light
# 15                11      17.00   light
# 16                11      13.33   light
# 17                 9      13.67   light
# 18                 9       7.67   heavy
# 19                 9      12.00   light

# %% [markdown]
# Binning all nominal variables to numeric bins

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'heavy'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-308-f33ea4c1336a> in <module>()
# ----> 1 drinking_bins['heavy'].counts()
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4715             # try that
#    4716             try:
# -> 4717                 iloc = self.get_loc(key)
#    4718                 return s[iloc]
#    4719             except KeyError:
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'heavy'

# %%
conditions=[df['Mjob'] == 'at_home',
          df['Mjob'] == 'services',
          df['Mjob'] == 'teacher',
          df['Mjob'] == 'health',
           df['Mjob']== 'other']
choices = [1,2,3,4,5]
df['Mjob'] = np.select(conditions, choices)

conditions=[df['Fjob'] == 'at_home',
          df['Fjob'] == 'services',
          df['Fjob'] == 'teacher',
          df['Fjob'] == 'health',
           df['Fjob']== 'other']
choices = [1,2,3,4,5]
df['Fjob'] = np.select(conditions, choices)

conditions=[df['reason'] == 'home',
          df['reason'] == 'reputation',
          df['reason'] == 'course',
           df['reason']== 'other']
choices = [1,2,3,4]
df['reason'] = np.select(conditions, choices)

conditions=[df['guardian'] == 'father',
          df['guardian'] == 'mother',
          df['guardian'] == 'other']
choices = [1,2,3]
df['guardian'] = np.select(conditions, choices)

# %%
df['Mjob'].value_counts()
# Out:
# 5    258
# 2    136
# 1    135
# 3     72
# 4     48
# Name: Mjob, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null int64
# Fjob          649 non-null int64
# reason        649 non-null int64
# guardian      649 non-null int64
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# freetime      649 non-null int64
# goout         649 non-null int64
# Dalc          649 non-null int64
# Walc          649 non-null int64
# health        649 non-null int64
# absences      649 non-null int64
# G1            649 non-null int64
# G2            649 non-null int64
# G3            649 non-null int64
# alc           649 non-null int64
# dtypes: int64(21), object(13)
# memory usage: 172.5+ KB

# %%
df['alc']= df['Dalc']+df['Walc']

df['alc'].value_counts()
# Out:
# 2     241
# 3     116
# 4      99
# 5      73
# 6      50
# 7      32
# 8      17
# 10     15
# 9       6
# Name: alc, dtype: int64

# %% [markdown]
# need to answer why using this type of binning? How does it help answer our business problem.

# %%
# if >=6 then heavy drinker, 1
df['alc'].where(df['alc']>=6, 0, inplace = True)
df['alc'].where(df['alc']<=5, 1, inplace = True)

print(df['alc'].value_counts())
print(df['alc'].value_counts(normalize = True))
# Out:
# 0    529
# 1    120
# Name: alc, dtype: int64
# 0    0.8151
# 1    0.1849
# Name: alc, dtype: float64

# %%
object_cols= df.select_dtypes(include=object).columns

# %%
# converting object columns to numeric 
for col in object_cols:
    df[col]= pd.to_numeric(df[col])
    
df.dtypes
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# Mjob          int64
# Fjob          int64
# reason        int64
# guardian      int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# alc           int64
# dtype: object

# %%
df.isna().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# alc           False
# dtype: bool

# %% [markdown]
# **Note:** How can you use this info during the modeling phase? Can you perform any variable significance to check this, for values only upto 18 years, or also more?

# %%
df[df['age'] >=19]['age'].count()
# Out:
# 41
